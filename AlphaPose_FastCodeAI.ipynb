# %% [markdown]
# <a href="https://colab.research.google.com/github/GrantorShadow/AlphaPose_NBK/blob/main/AlphaPose_FastCodeAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # prep files

# %%
! pip install pyyaml==5.2
! pip install scipy==1.1.0
! pip install torch==1.2.0 torchvision==0.4.0
! pip install pillow==6.2.2
! pip install ffmpeg
import os
import torch
print(torch.__version__)
import yaml, scipy, os
print(yaml.__version__)
print(scipy.__version__)
# Out:
# ...
#      |████████████████████████████████| 265 kB 13.5 MB/s
# ...
#   Created wheel for pyyaml: filename=PyYAML-5.2-cp37-cp37m-linux_x86_64.whl size=44225 sha256=1be36556abc7674394390d80dc9a0ae367f6d034698c5675a55fc1ea7b7c2bfe
#   Stored in directory: /root/.cache/pip/wheels/c5/67/65/80b02387630c3794fc9bab68ca0de3dd87d639d65936026527
# Successfully built pyyaml
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 31.2 MB 173 kB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc3 3.11.4 requires scipy>=1.2.0, but you have scipy 1.1.0 which is incompatible.
# ...

# %%
# !rm -rf /content/AlphaPose
os.chdir('/content/')
# !git clone https://github.com/MVIG-SJTU/AlphaPose.git
# Out:
# Cloning into 'AlphaPose'...
# remote: Enumerating objects: 2278, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 2278 (delta 7), reused 0 (delta 0), pack-reused 2245
# Receiving objects: 100% (2278/2278), 108.47 MiB | 24.66 MiB/s, done.
# Resolving deltas: 100% (1110/1110), done.

# %%
# !python -m pip install cython
# !sudo apt-get install libyaml-dev
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libyaml-doc
# The following NEW packages will be installed:
#   libyaml-dev
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 55.7 kB of archives.
# After this operation, 246 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libyaml-dev amd64 0.1.7-2ubuntu3 [55.7 kB]
# Fetched 55.7 kB in 0s (1,084 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
os.chdir('/content/AlphaPose')
print(os.getcwd())
! python setup.py build develop
# Out:
# /content/AlphaPose
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.7
# creating build/lib.linux-x86_64-3.7/trackers
# copying trackers/__init__.py -> build/lib.linux-x86_64-3.7/trackers
# copying trackers/tracker_cfg.py -> build/lib.linux-x86_64-3.7/trackers
# copying trackers/tracker_api.py -> build/lib.linux-x86_64-3.7/trackers
# creating build/lib.linux-x86_64-3.7/alphapose
# copying alphapose/version.py -> build/lib.linux-x86_64-3.7/alphapose
# copying alphapose/opt.py -> build/lib.linux-x86_64-3.7/alphapose
# copying alphapose/__init__.py -> build/lib.linux-x86_64-3.7/alphapose
# creating build/lib.linux-x86_64-3.7/trackers/ReidModels
# copying trackers/ReidModels/osnet_ain.py -> build/lib.linux-x86_64-3.7/trackers/ReidModels
# copying trackers/ReidModels/osnet.py -> build/lib.linux-x86_64-3.7/trackers/ReidModels
# copying trackers/ReidModels/__init__.py -> build/lib.linux-x86_64-3.7/trackers/ReidModels
# ...

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

! mkdir /content/AlphaPose/detector/yolo/data
file_id = '1D47msNOOiJKvPOXlnpyzdKA3k6E97NTC'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/AlphaPose/detector/yolo/data/yolov3-spp.weights')

! mkdir /content/AlphaPose/detector/tracker/data
file_id = '1nlnuYfGNuHWZztQHXwVZSL_FvfE551pA'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/AlphaPose/detector/tracker/data/JDE-1088x608-uncertainty')

file_id = '1kQhnMRURFiy7NsdS8EFL-8vtqEXOgECn'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/AlphaPose/pretrained_models/fast_res50_256x192.pth')

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # run files

# %%
import glob
import subprocess

video_file_names = glob.glob("/content/gdrive/MyDrive/FastCode_AI_HumanPose_PoC/*.mp4")
frame_rate = 30

# remember to change into the parent directory at the end 
for file_name in video_file_names:
  # %cd /content/
  print("\n")
  print("now processing... ->", os.path.basename(file_name))
  
  video_name = os.path.basename(file_name).split(".")[0]
  frame_folder_path = os.path.join("/content/", str(video_name))
  # frame_folder_path = os.path.dirname(frame_folder_path)
  if not os.path.exists(frame_folder_path):
    print("creating directory...", frame_folder_path)
    os.makedirs(frame_folder_path)
  else:
    print(frame_folder_path, "already exists ; proceeding...")

  # processed_path = os.path.dirname("video_path/processed_files")
  processed_path = os.path.join(frame_folder_path, "processed_files")
  if not os.path.exists(processed_path):
    print("creating directory...", processed_path)
    os.makedirs(processed_path)
  else:
    print(processed_path, "already exists ; proceeding...")

  os.chdir(frame_folder_path)
  ffmpeg_command_vid2frames = ["ffmpeg", "-i", file_name,  "input-%03d.jpg"]
  subprocess.run(ffmpeg_command_vid2frames, capture_output=True)
  print("extracted frames... applying AlphaPose Algo")

  os.chdir('/content/AlphaPose')

  ! python3 scripts/demo_inference.py --cfg configs/coco/resnet/256x192_res50_lr1e-3_1x.yaml --checkpoint pretrained_models/fast_res50_256x192.pth --indir examples/demo/ --outdir frame_folder_path/processed_files/ --save_img

  
  # alpha_pose_command = ["python", "scripts/demo_inference.py", 
  #                       "--cfg", "configs/coco/resnet/256x192_res50_lr1e-3_1x.yaml", 
  #                       "--checkpoint", "pretrained_models/fast_res50_256x192.pth", 
  #                       "--indir", "frame_folder_path", 
  #                       "--save_img"]

  #  "--outdir", "frame_folder_path/processed_files/"
  
  if subprocess.run(alpha_pose_command, capture_output=True).returncode == 0:
    print("process ran successfully")
  
  os.chdir("/content/")

  ffmpeg_command_frames2vid = ["ffmpeg", "-framerate", "frame_rate", "-pattern_type",  "glob", "-i", "input-*.jpg", "file_name"]
  subprocess.run(ffmpeg_command_frames2vid)

  print("finished processing... ->", file_name)

print("\n", "finished processing", len(video_file_names), "files")
# Out:
# now processing... -> HighKnees.mp4
# /content/HighKnees already exists ; proceeding...
# /content/HighKnees/processed_files already exists ; proceeding...
# extracted frames... applying AlphaPose Algo
# process ran successfully
# finished processing... -> /content/gdrive/MyDrive/FastCode_AI_HumanPose_PoC/HighKnees.mp4
#
#
# now processing... -> Pushups.mp4
# /content/Pushups already exists ; proceeding...
# /content/Pushups/processed_files already exists ; proceeding...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-d2f7973bd0cf> in <module>()
#      30   os.chdir(frame_folder_path)
#      31   ffmpeg_command_vid2frames = ["ffmpeg", "-i", file_name,  "input-%03d.jpg"]
# ---> 32   subprocess.run(ffmpeg_command_vid2frames, capture_output=True)
#      33   print("extracted frames... applying AlphaPose Algo")
#      34
#
# ...

# %%
# import os
# os.chdir('/content/AlphaPose')
# ! ls
# ! python3 scripts/demo_inference.py --cfg configs/coco/resnet/256x192_res50_lr1e-3_1x.yaml --checkpoint pretrained_models/fast_res50_256x192.pth --indir examples/demo/ --save_img
# # result json and rendered images are saved here:
# ! ls examples/res/
# ! ls examples/res/vis
# Out:
# alphapose	    configs   examples		 pretrained_models  setup.cfg
# alphapose.egg-info  detector  frame_folder_path  README.md	    setup.py
# build		    docs      LICENSE		 scripts	    trackers
# Loading pose model from pretrained_models/fast_res50_256x192.pth...
# Loading YOLO model..
# 100% 3/3 [00:01<00:00,  2.34it/s]
# ===========================> Finish Model Running.
# ===========================> Rendering remaining images in the queue...
# ===========================> If this step takes too long, you can enable the --vis_fast flag to use fast rendering (real-time).
# Process Process-4:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/content/AlphaPose/alphapose/utils/writer.py", line 179, in update
# ...
